# %%
import pandas as pd

# %%
df = pd.read_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged.csv')

# %%
# sample 0.3 of the dataset
df_sampled = df.sample(frac=0.1, random_state=42)

# %%
df_sampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302250 entries, 183448 to 2857404
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           302250 non-null  object
#  1   gender            302250 non-null  object
#  2   country           302250 non-null  object
#  3   timestamp         302250 non-null  object
#  4   track_id          302250 non-null  object
#  5   artist_name       302250 non-null  object
#  6   track_name        302250 non-null  object
#  7   album_name        302250 non-null  object
#  8   popularity        302250 non-null  int64
#  9   danceability      302250 non-null  float64
#  10  energy            302250 non-null  float64
#  11  key               302250 non-null  int64
#  12  loudness          302250 non-null  float64
#  13  duration_ms       302250 non-null  int64
#  14  explicit          302250 non-null  bool
#  15  mode              302250 non-null  int64
#  16  speechiness       302250 non-null  float64
#  17  acousticness      302250 non-null  float64
#  18  instrumentalness  302250 non-null  float64
#  19  liveness          302250 non-null  float64
#  20  valence           302250 non-null  float64
#  21  tempo             302250 non-null  float64
#  22  time_signature    302250 non-null  int64
#  23  track_genre       302250 non-null  object
# dtypes: bool(1), float64(9), int64(5), object(9)
# memory usage: 55.6+ MB

# %%
df_sampled.to_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged_0.1.csv', index=False)
