# %%
import pandas as pd

# %%
df = pd.read_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged.csv')

# %%
print(f"Canciones unicas artista-cancion: {(df['artist_name'] + df['track_name']).nunique()}")
# Out:
# Canciones unicas artista-cancion: 10681

# %%
print(f"Canciones unicas por track_id: {df['track_id'].nunique()}")
# Out:
# Canciones unicas por track_id: 10135

# %%
df_songs = pd.read_csv('../data/spotify-kaggle/interim/songs_catalog.csv')

# %%
df_songs.loc[df_songs['track_id'] == '5CSEaABQkS1hoLza0IpK2r',:]
# Out:
#     artist_name    track_name                track_id
# 420  Amar Arshi  Kala Chashma  5CSEaABQkS1hoLza0IpK2r

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os

from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env")

SPOTIFY_CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
SPOTIFY_CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=SPOTIFY_CLIENT_ID,
                                                           client_secret=SPOTIFY_CLIENT_SECRET))

# %%
sp.track("2QsIFeMrlMFhybtglj3PcK")
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f7Qfkua3IcRpUFzUaUnrX'},
#     'href': 'https://api.spotify.com/v1/artists/3f7Qfkua3IcRpUFzUaUnrX',
#     'id': '3f7Qfkua3IcRpUFzUaUnrX',
#     'name': 'Amar Arshi',
#     'type': 'artist',
#     'uri': 'spotify:artist:3f7Qfkua3IcRpUFzUaUnrX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
sp.track("5CSEaABQkS1hoLza0IpK2r")
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5ASFrellizlx98SmsItOEm'},
#   'href': 'https://api.spotify.com/v1/albums/5ASFrellizlx98SmsItOEm',
#   'id': '5ASFrellizlx98SmsItOEm',
#   'images': [],
#   'name': '',
#   'release_date': '0000',
#   'release_date_precision': 'year',
#   'total_tracks': 6,
#   'type': 'album',
#   'uri': 'spotify:album:5ASFrellizlx98SmsItOEm'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#    'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
# ...

# %%
# %load_ext cudf.pandas

import pandas as pd

# %%
df_merged = pd.read_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged.csv')

# %%
# Reparar el track_id invalido
df_merged.loc[df_merged['track_id'] == '5CSEaABQkS1hoLza0IpK2r',"track_id"] = "2QsIFeMrlMFhybtglj3PcK"

# %%
df_songs = pd.read_csv('../data/spotify-kaggle/interim/songs_catalog.csv')

# %%
df_songs.loc[df_songs['track_id'] == '5CSEaABQkS1hoLza0IpK2r',"track_id"] = "2QsIFeMrlMFhybtglj3PcK"

# %%
df_merged.to_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged.csv', index=False)
df_songs.to_csv('../data/spotify-kaggle/interim/songs_catalog.csv', index=False)
