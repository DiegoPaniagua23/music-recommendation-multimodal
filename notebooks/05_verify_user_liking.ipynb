# %%
import pandas as pd

# %%
df_merged = pd.read_csv('../data/spotify-kaggle/interim/lastfm_spotify_merged_0.1.csv')

# %%
user = "user_000238"

# %%
df_merged.loc[df_merged['user_id'] == user, ['track_id', 'artist_name', 'track_name']]
# Out:
#                       track_id            artist_name  \
# 0       2vQQfWTanvD99OeHLAoyhW         Arctic Monkeys
# 26      0k2GOhqsrxDTAbFFSdNJjT              Sean Paul
# 131     6lnnaGN20kl0jEYJSxCgU9            The Strokes
# 1238    3pRaLNL3b8x5uBOcsgvdqM           Jeff Buckley
# 1445    70wYA8oYHoMzhRRkARoMhU            The Killers
# ...                        ...                    ...
# 299534  2N20grTTADa1DP1DWBsCIe          The Fratellis
# 299564  5KGbRvZyVyKP2AEJMHErB4         Arctic Monkeys
# 299674  2ndWbjiiNBEOrlfToKlABE    Death Cab For Cutie
# 300349  3dPQuX8Gs42Y7b454ybpMR      The White Stripes
# 301963  2aibwv5hGXSgw7Yru8IYTO  Red Hot Chili Peppers
#
#                              track_name
# 0           From The Ritz To The Rubble
# 26                          Temperature
# 131               You Talk Way Too Much
# 1238                         Hallelujah
# 1445                When You Were Young
# ...                                 ...
# ...

# %%
recommendations = """  1. Tinariwen - Cler Achel (Score: 0.5191)
  2. Klaxons - Golden Skans (Score: 0.5007)
  3. Mgmt - Kids (Score: 0.4815)
  4. Arctic Monkeys - Plastic Tramp (Score: 0.4807)
  5. Chuck Ragan - The Boat (Score: 0.4798)
  6. Mgmt - Time to Pretend (Score: 0.4780)
  7. Arctic Monkeys - Too Much To Ask (Score: 0.4767)
  8. Mgmt - Electric Feel (Score: 0.4765)
  9. Arctic Monkeys - Cigarette Smoker Fiona (Score: 0.4750)
  10. Paolo Nutini - New Shoes (Score: 0.4742)"""
  
recom_list = [line.split(" - ")[1].split(" (Score:")[0] for line in recommendations.split("\n")]
recom_list
# Out:
# ['Cler Achel',
#  'Golden Skans',
#  'Kids',
#  'Plastic Tramp',
#  'The Boat',
#  'Time to Pretend',
#  'Too Much To Ask',
#  'Electric Feel',
#  'Cigarette Smoker Fiona',
#  'New Shoes']
