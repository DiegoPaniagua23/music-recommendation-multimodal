# %%
import pandas as pd

# %%
df_cisar = pd.read_csv('../data/spotify-kaggle/interim/lyrics_dataset_10k.csv')

# %%
df_cisar.head()
# Out:
#                  track_id                                             lyrics  \
# 0  3WMbD1OyfKuwWDWMNbPQ4g  [Intro]\nShe's crazy like a fool\nWild about D...
# 1  0lCpIGHKCbzZQpWLkXkzbY  [Intro]\nAin't nothing working\nAin't nothing ...
# 2  70lx4p91JrDXfuIYYadNcK  I'm so intoxicated\nI feel supernatural\nI'm s...
# 3  31rnnZ6CHu9ouzDaoSDyON  [Hook]\nWhy don't you just spread your legs an...
# 4  3utBUqVxYMlm9p6nYh0eus  Well it gets so hard to keep my he'd up\nThis ...
#
#   status
# 0  found
# 1  found
# 2  found
# 3  found
# 4  found

# %%
df_cisar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10681 entries, 0 to 10680
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   track_id  10681 non-null  object
#  1   lyrics    8544 non-null   object
#  2   status    10681 non-null  object
# dtypes: object(3)
# memory usage: 250.5+ KB

# %%
# Fix incorrect track_id
df_cisar.loc[df_cisar['track_id'] == '5CSEaABQkS1hoLza0IpK2r',"track_id"] = "2QsIFeMrlMFhybtglj3PcK"

# %%
df_cisar.to_csv('../data/spotify-kaggle/interim/lyrics_dataset_10k_fixed.csv', index=False)
